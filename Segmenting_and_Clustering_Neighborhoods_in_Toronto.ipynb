# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %%
import pandas as pd
from pandas.io.json import json_normalize # transform json file into pandas dataframe
import folium
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %% [markdown]
# #### Scrape data from wikipedia

# %%
import requests
from lxml import html

# %%
response = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
tree = html.document_fromstring(response.text)
d={}
d['postcode']=tree.xpath("//table[@class = 'wikitable sortable']/tbody/tr/td[1]/text()")
d['borough']=[x.xpath('string(.)') for x in tree.xpath("//table[@class = 'wikitable sortable']/tbody/tr/td[2]")]
d['neighborhood']=[x.xpath('string(.)').replace('\n','')  for x in tree.xpath("//table[@class = 'wikitable sortable']/tbody/tr/td[3]")]

df = pd.DataFrame(d)

# %%
df.head(20)
# Out:
#    postcode           borough      neighborhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Queen's Park
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern
# 14      M3B        North York   Don Mills North
# 15      M4B         East York  Woodbine Gardens
# 16      M4B         East York     Parkview Hill
# 17      M5B  Downtown Toronto           Ryerson
# 18      M5B  Downtown Toronto   Garden District
# 19      M6B        North York         Glencairn
# 22      M9B         Etobicoke        Cloverdale
# 23      M9B         Etobicoke         Islington
# 24      M9B         Etobicoke      Martin Grove
# 25      M9B         Etobicoke  Princess Gardens

# %% [markdown]
# #### Drop records with borough "Not assigned"

# %%
df = df.drop(df.loc[df.borough=='Not assigned'].index)

# %% [markdown]
# #### Rename neighborhood name with borough name where neighborhood is still "Not assigned"

# %%
for i in df.index:
    if df.loc[i].neighborhood == 'Not assigned':
        df.loc[i,'neighborhood']=df.loc[i].borough

# %%
grouped_df = df.groupby('postcode')
result_df = pd.DataFrame(columns=['Postcode','Borough','Neighborhood'])

# %%
for postcode in grouped_df.groups.keys():
    br = grouped_df.get_group(postcode)['borough'].iloc[0]
    nei = ','.join(grouped_df.get_group(postcode)['neighborhood'].values)
    result_df = result_df.append({'Postcode':postcode,'Borough':br,'Neighborhood':nei},ignore_index=True)

# %%
print(result_df.shape)
result_df
# Out:
# (103, 3)
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                           Neighborhood
# 0                                        Rouge,Malvern
# 1                 Highland Creek,Rouge Hill,Port Union
# 2                      Guildwood,Morningside,West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6            East Birchmount Park,Ionview,Kennedy Park
# 7                        Clairlea,Golden Mile,Oakridge
# 8        Cliffcrest,Cliffside,Scarborough Village West
# 9                           Birch Cliff,Cliffside West
# 10   Dorset Park,Scarborough Town Centre,Wexford He...
# 11                                    Maryvale,Wexford
# 12                                           Agincourt
# 13               Clarks Corners,Sullivan,Tam O'Shanter
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                          Fairview,Henry Farm,Oriole
# 19                                     Bayview Village
# 20                             Silver Hills,York Mills
# 21                              Newtonbrook,Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                     Flemingdon Park,Don Mills South
# 28       Bathurst Manor,Downsview North,Wilson Heights
# 29                      Northwood Park,York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                         Dovercourt Village,Dufferin
# 77                             Little Portugal,Trinity
# 78          Brockton,Exhibition Place,Parkdale Village
# 79                    Downsview,North Park,Upwood Park
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 81                        The Junction North,Runnymede
# 82                        High Park,The Junction South
# 83                               Parkdale,Roncesvalles
# 84                                   Runnymede,Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88          Humber Bay Shores,Mimico South,New Toronto
# 89                               Alderwood,Long Branch
# 90         The Kingsway,Montgomery Road,Old Mill North
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...
# 92   Kingsway Park South West,Mimico NW,The Queensw...
# 93                                    Islington Avenue
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...
# 96                                       Humber Summit
# 97                                     Emery,Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village,Martin Grove Gardens,Richvie...
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# #### Reading geographical coordinates

# %%
geo_df = pd.read_csv('Geospatial_Coordinates.csv')
geo_df.columns=['Postcode','Latitude','Longitude']

# %%
result_df = result_df.join(geo_df.set_index('Postcode'), on='Postcode')

# %%
result_df['n_neighborhood'] = result_df['Neighborhood'].apply(lambda x : len(x.split(',')))

# %%
result_df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
#      n_neighborhood
# 0                 2
# 1                 3
# 2                 3
# 3                 1
# 4                 1
# 5                 1
# 6                 3
# 7                 3
# 8                 3
# 9                 2
# 10                3
# 11                2
# 12                1
# 13                3
# 14                4
# 15                1
# 16                1
# 17                1
# 18                3
# 19                1
# 20                2
# 21                2
# 22                1
# 23                1
# 24                1
# 25                1
# 26                1
# 27                2
# 28                3
# 29                2
# ..              ...
# 73                1
# 74                1
# 75                1
# 76                2
# 77                2
# 78                3
# 79                3
# 80                4
# 81                2
# 82                2
# 83                2
# 84                2
# 85                1
# 86                1
# 87                1
# 88                3
# 89                2
# 90                3
# 91                8
# 92                5
# 93                1
# 94                5
# 95                4
# 96                1
# 97                2
# 98                1
# 99                1
# 100               4
# 101               8
# 102               1
#
# [103 rows x 6 columns]

# %% [markdown]
# #### Visualization of neighborhoods' location

# %%
result_df.Borough.unique().size
# Out:
# 11

# %%
toronto = folium.Map([43.7153834, -79.40567840000001],zoom_start=11)

#add markers for each postcode zone on the map
for i in result_df.index:
    coordinate = [result_df.loc[i].Latitude,result_df.loc[i].Longitude]
    boro = result_df.loc[i].Borough
#     folium.Marker(coordinate,popup=str(boro)).add_to(toronto)
    folium.Circle(coordinate,radius=200,popup=str(boro)).add_to(toronto)
toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Using Foursquare api to explore these region

# %%
CLIENT_ID = 'GBIVTOMHIWPLGPG4HZ0EXCZZ1H3RL2BOEBV3TVMN253WU43F' 
CLIENT_SECRET = 'FAUTZDAWQ1RA4TV0F22BAROLZBUV2EDE5BKX0WWAAPWXASV1' 
VERSION = '20180605'

# %% [markdown]
# Create the GET request url

# %% [markdown]
# #### Let' s take a look at M6G Downtown Toronto

# %%
LIMIT = 100
radius = 500
neighborhood_latitude = 43.669542
neighborhood_longitude = -79.422564
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
result_4square = requests.get(url).json()

# %%
result_4square
# Out:
# {'meta': {'code': 200, 'requestId': '5d586775e0c0c90038a33035'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcfd7cf964a5203e6321e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4adcfd7cf964a5203e6321e3',
#        'location': {'address': '200 Christie St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Essex St',
#         'distance': 205,
#         'formattedAddress': ['200 Christie St (at Essex St)',
#          'Toronto ON M6G 3B6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66847077052224,
#           'lng': -79.42048512748114}],
#         'lat': 43.66847077052224,
#         'lng': -79.42048512748114,
#         'postalCode': 'M6G 3B6',
#         'state': 'ON'},
#        'name': 'Fiesta Farms',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '56848730'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-540c8301498e51456f71ae7e-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '540c8301498e51456f71ae7e',
#        'location': {'address': '1028 Shaw St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Yarmouth',
#         'distance': 289,
#         'formattedAddress': ['1028 Shaw St (Yarmouth)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.669107144072974,
#           'lng': -79.42610471852032}],
#         'lat': 43.669107144072974,
#         'lng': -79.42610471852032,
#         'state': 'ON'},
#        'name': 'Contra Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b003cf6f964a520d73b22e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4b003cf6f964a520d73b22e3',
#        'location': {'address': '787 Dupont Street',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 315,
#         'formattedAddress': ['787 Dupont Street',
#          'Toronto ON M6G 1Z5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67067884412717,
#           'lng': -79.42614819830024}],
#         'lat': 43.67067884412717,
#         'lng': -79.42614819830024,
#         'postalCode': 'M6G 1Z5',
#         'state': 'ON'},
#        'name': 'Vinny’s Panini',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dc9d2add4c07b350108956a-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4dc9d2add4c07b350108956a',
#        'location': {'address': '657 Dupont St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Christie St.',
#         'distance': 247,
#         'formattedAddress': ['657 Dupont St (at Christie St.)',
#          'Toronto ON M6G 1Z4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.671585333016466,
#           'lng': -79.42136550708386}],
#         'lat': 43.671585333016466,
#         'lng': -79.42136550708386,
#         'postalCode': 'M6G 1Z4',
#         'state': 'ON'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adb4d20f964a520b12521e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'primary': True,
#          'shortName': 'Diner'}],
#        'id': '4adb4d20f964a520b12521e3',
#        'location': {'address': '1071 Shaw St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Dupont',
#         'distance': 339,
#         'formattedAddress': ['1071 Shaw St. (Dupont)', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.670549820711926,
#           'lng': -79.42654054306477}],
#         'lat': 43.670549820711926,
#         'lng': -79.42654054306477,
#         'state': 'ON'},
#        'name': 'Universal Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f737b84e4b060af1b23c5b7-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4f737b84e4b060af1b23c5b7',
#        'location': {'address': '971 Ossington Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 480,
#         'formattedAddress': ['971 Ossington Ave',
#          'Toronto ON M6G 3V5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66785822046965,
#           'lng': -79.42805427320322}],
#         'lat': 43.66785822046965,
#         'lng': -79.42805427320322,
#         'postalCode': 'M6G 3V5',
#         'state': 'ON'},
#        'name': 'Actinolite',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-536e42af498e8a0880b220d7-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '536e42af498e8a0880b220d7',
#        'location': {'address': '146 Christie Street',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Bloor',
#         'distance': 322,
#         'formattedAddress': ['146 Christie Street (Bloor)',
#          'Toronto ON M6G 3B3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66735987720157,
#           'lng': -79.41993774586636}],
#         'lat': 43.66735987720157,
#         'lng': -79.41993774586636,
#         'postalCode': 'M6G 3B3',
#         'state': 'ON'},
#        'name': 'Scout and Cash Caffe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85621950'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ade0037f964a520396721e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4ade0037f964a520396721e3',
#        'location': {'address': '672 Dupont Street',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Christie',
#         'distance': 311,
#         'formattedAddress': ['672 Dupont Street (Christie)',
#          'Toronto ON M6G 1Z6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6710456734398,
#           'lng': -79.41929697990417}],
#         'lat': 43.6710456734398,
#         'lng': -79.41929697990417,
#         'postalCode': 'M6G 1Z6',
#         'state': 'ON'},
#        'name': 'Faema Caffe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4aee0faef964a520b1d121e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4aee0faef964a520b1d121e3',
#        'location': {'address': '650 Dupont St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Christie St.',
#         'distance': 278,
#         'formattedAddress': ['650 Dupont St (at Christie St.)',
#          'Toronto ON M6G 4B1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.671806531827656,
#           'lng': -79.42110162429452}],
#         'lat': 43.671806531827656,
#         'lng': -79.42110162429452,
#         'postalCode': 'M6G 4B1',
#         'state': 'ON'},
#        'name': 'Loblaws',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bb799a07421a593dcb9c040-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b32',
#          'name': 'Baby Store',
#          'pluralName': 'Baby Stores',
#          'primary': True,
#          'shortName': 'Baby Store'}],
#        'id': '4bb799a07421a593dcb9c040',
#        'location': {'address': '631 Dupont St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 303,
#         'formattedAddress': ['631 Dupont St', 'Toronto ON M6G 1Z4', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.671824,
#           'lng': -79.420499}],
#         'lat': 43.671824,
#         'lng': -79.420499,
#         'postalCode': 'M6G 1Z4',
#         'state': 'ON'},
#        'name': 'Marlenes Just Babies',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d72ca285838a09358d410db-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'primary': True,
#          'shortName': 'Nightclub'}],
#        'id': '4d72ca285838a09358d410db',
#        'location': {'address': '807 Dupont St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Shaw St.',
#         'distance': 342,
#         'formattedAddress': ['807 Dupont St. (Shaw St.)',
#          'Toronto ON M6G 1Z7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67048982553482,
#           'lng': -79.42661141389264}],
#         'lat': 43.67048982553482,
#         'lng': -79.42661141389264,
#         'postalCode': 'M6G 1Z7',
#         'state': 'ON'},
#        'name': 'Dupont Disco',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfc2a7fe05e0f47b348cfa8-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'primary': True,
#          'shortName': 'Athletics & Sports'}],
#        'id': '4bfc2a7fe05e0f47b348cfa8',
#        'location': {'address': '568 Dupont St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 478,
#         'formattedAddress': ['568 Dupont St.', 'Toronto ON M6G 1Y9', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.672386069777616,
#           'lng': -79.41810570233238}],
#         'lat': 43.672386069777616,
#         'lng': -79.41810570233238,
#         'postalCode': 'M6G 1Y9',
#         'state': 'ON'},
#        'name': 'Queens Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b86818cf964a520218d31e3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'primary': True,
#          'shortName': 'Convenience Store'}],
#        'id': '4b86818cf964a520218d31e3',
#        'location': {'address': '860 Dupont St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Ossington',
#         'distance': 478,
#         'formattedAddress': ['860 Dupont St. (Ossington)',
#          'Toronto ON M6C 1Z8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67035525082211,
#           'lng': -79.42840047898076}],
#         'lat': 43.67035525082211,
#         'lng': -79.42840047898076,
#         'postalCode': 'M6C 1Z8',
#         'state': 'ON'},
#        'name': 'Pioneer Gas',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c840c82d8086dcbcfcb8552-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4c840c82d8086dcbcfcb8552',
#        'location': {'address': '285 Melita Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 482,
#         'formattedAddress': ['285 Melita Avenue',
#          'Toronto ON M6G 3W7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67375357657298,
#           'lng': -79.42398759247811}],
#         'lat': 43.67375357657298,
#         'lng': -79.42398759247811,
#         'postalCode': 'M6G 3W7',
#         'state': 'ON'},
#        'name': 'Marian Engel Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d8fe809cb9b224bd1c3a541-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4d8fe809cb9b224bd1c3a541',
#        'location': {'address': '1152 Shaw',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Dupont',
#         'distance': 485,
#         'formattedAddress': ['1152 Shaw (Dupont)', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67168977827157,
#           'lng': -79.42780494689941}],
#         'lat': 43.67168977827157,
#         'lng': -79.42780494689941,
#         'state': 'ON'},
#        'name': 'Garrison Creek Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c176f94f1c976b05620a272-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4c176f94f1c976b05620a272',
#        'location': {'address': '972 Ossington',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 487,
#         'formattedAddress': ['972 Ossington', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66797858931121,
#           'lng': -79.42821689567089}],
#         'lat': 43.66797858931121,
#         'lng': -79.42821689567089,
#         'state': 'ON'},
#        'name': 'Foto Grocery',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Christie Pits, Toronto',
#   'headerLocation': 'Christie Pits',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.6740420045, 'lng': -79.41635441972038},
#    'sw': {'lat': 43.6650419955, 'lng': -79.42877358027961}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 16}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = result_4square['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# %%
nearby_venues
# Out:
#               venue.name                                   venue.categories  \
# 0           Fiesta Farms  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 1            Contra Cafe  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 2         Vinny’s Panini  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 3              Starbucks  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 4        Universal Grill  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...
# 5             Actinolite  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 6   Scout and Cash Caffe  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 7            Faema Caffe  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 8                Loblaws  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 9   Marlenes Just Babies  [{'id': '52f2ab2ebcbc57f1066b8b32', 'name': 'B...
# 10          Dupont Disco  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...
# 11           Queens Club  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 12           Pioneer Gas  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 13     Marian Engel Park  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 14   Garrison Creek Park  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 15          Foto Grocery  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
#
#     venue.location.lat  venue.location.lng
# 0            43.668471          -79.420485
# 1            43.669107          -79.426105
# 2            43.670679          -79.426148
# 3            43.671585          -79.421366
# 4            43.670550          -79.426541
# 5            43.667858          -79.428054
# 6            43.667360          -79.419938
# 7            43.671046          -79.419297
# 8            43.671807          -79.421102
# 9            43.671824          -79.420499
# 10           43.670490          -79.426611
# 11           43.672386          -79.418106
# 12           43.670355          -79.428400
# 13           43.673754          -79.423988
# 14           43.671690          -79.427805
# 15           43.667979          -79.428217

# %%
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#               name          categories        lat        lng
# 0     Fiesta Farms       Grocery Store  43.668471 -79.420485
# 1      Contra Cafe                Café  43.669107 -79.426105
# 2   Vinny’s Panini  Italian Restaurant  43.670679 -79.426148
# 3        Starbucks         Coffee Shop  43.671585 -79.421366
# 4  Universal Grill               Diner  43.670550 -79.426541

# %%
nearby_venues
# Out:
#                     name          categories        lat        lng
# 0           Fiesta Farms       Grocery Store  43.668471 -79.420485
# 1            Contra Cafe                Café  43.669107 -79.426105
# 2         Vinny’s Panini  Italian Restaurant  43.670679 -79.426148
# 3              Starbucks         Coffee Shop  43.671585 -79.421366
# 4        Universal Grill               Diner  43.670550 -79.426541
# 5             Actinolite          Restaurant  43.667858 -79.428054
# 6   Scout and Cash Caffe                Café  43.667360 -79.419938
# 7            Faema Caffe                Café  43.671046 -79.419297
# 8                Loblaws       Grocery Store  43.671807 -79.421102
# 9   Marlenes Just Babies          Baby Store  43.671824 -79.420499
# 10          Dupont Disco           Nightclub  43.670490 -79.426611
# 11           Queens Club  Athletics & Sports  43.672386 -79.418106
# 12           Pioneer Gas   Convenience Store  43.670355 -79.428400
# 13     Marian Engel Park                Park  43.673754 -79.423988
# 14   Garrison Creek Park                Park  43.671690 -79.427805
# 15          Foto Grocery       Grocery Store  43.667979 -79.428217

# %% [markdown]
# #### Visualize the nearby venues

# %%
center_map=folium.Map([43.668471,-79.420485],zoom_start=15)
for i in nearby_venues.index:
    coordinate = [nearby_venues.loc[i].lat,nearby_venues.loc[i].lng]
    folium.Marker(coordinate,popup=str(nearby_venues.loc[i]['name'])+' \nCategory:'+str(nearby_venues.loc[i].categories)).add_to(center_map)
                  
                  
center_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
